# %%
import requests
import random
from bs4 import BeautifulSoup as bs
from selenium import webdriver

# %%
#driver=webdriver.Edge('./msedgedriver.exe')
#url="https://ca.finance.yahoo.com/quote/OTEX?p=OTEX"
#driver.get(url)
#soup = bs(driver.page_source, 'html.parser')
#print(soup.prettify())

# %%
headers = {'User-Agent': ""}
page = requests.get("https://ca.finance.yahoo.com/quote/OTEX?p=OTEX",headers=headers)
soup=bs(page.text,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="NoJs desktop" data-color-theme="light" id="atomic" lang="en-CA">
#  <head prefix="og: https://ogp.me/ns#">
#   <script>
#    window.performance && window.performance.mark && window.performance.mark('PageStart');
#   </script>
#   <meta charset="utf-8"/>
#   <title>
#    Open Text Corporation (OTEX) Stock Price, News, Quote &amp; History - Yahoo Finance
#   </title>
#   <meta content="OTEX, Open Text Corporation, OTEX stock chart, Open Text Corporation stock chart, stock chart, stocks, quotes, finance" name="keywords"/>
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <meta content="on" property="twitter:dnt"/>
#   <meta content="168824166370" property="fb:app_id"/>
#   <meta content="#400090" name="theme-color"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
# ...

# %%
quote_summary_table=soup.find(class_="My(0) P(0) Wow(bw) Ov(h)")
print(quote_summary_table.prettify())
# Out:
# <ul class="My(0) P(0) Wow(bw) Ov(h)">
#  <li class="js-stream-content Pos(r)">
#   <div class="Py(14px) Pos(r)" data-test-locator="mega">
#    <div class="Cf">
#     <div class="Fl(start) Pos(r) Mt(2px) W(26.5%) Maw(220px)">
#      <div class="H(0) Ov(h) Bdrs(2px)" style="padding-bottom:56%">
#       <img alt="" class="W(100%) Trsdu(0s)! Bdrs(2px)" src="https://s.yimg.com/uu/api/res/1.2/9rbPJdzgQ_X1lYiuXY9RCg--~B/Zmk9c3RyaW07aD0xMjM7cT04MDt3PTIyMDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/simply_wall_st__316/41bdd0c670f621394929d5266c5d6c72.cf.jpg" srcset="https://s.yimg.com/uu/api/res/1.2/9rbPJdzgQ_X1lYiuXY9RCg--~B/Zmk9c3RyaW07aD0xMjM7cT04MDt3PTIyMDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/simply_wall_st__316/41bdd0c670f621394929d5266c5d6c72.cf.jpg 1x,https://s.yimg.com/uu/api/res/1.2/l.hZxD7NSRVXAS5rNGWI2Q--~B/Zmk9c3RyaW07aD0yNDY7cT04MDt3PTQ0MDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/simply_wall_st__316/41bdd0c670f621394929d5266c5d6c72.cf.jpg 2x"/>
# ...

# %%
quote_summary_table=soup.find(id="quoteNewsStream-0-Stream")
print(quote_summary_table.prettify())
# Out:
# <div class="tdv2-applet-stream Bdc(#e2e2e6) Pos(r) Z(1)" id="quoteNewsStream-0-Stream" style="max-width:900px">
#  <ul class="My(0) P(0) Wow(bw) Ov(h)">
#   <li class="js-stream-content Pos(r)">
#    <div class="Py(14px) Pos(r)" data-test-locator="mega">
#     <div class="Cf">
#      <div class="Fl(start) Pos(r) Mt(2px) W(26.5%) Maw(220px)">
#       <div class="H(0) Ov(h) Bdrs(2px)" style="padding-bottom:56%">
# ...

# %%
table_rows = quote_summary_table.find_all('a')
print(table_rows)
#ad_name= quote_summary_table.find_all(class_=)
# Out:
# [<a class="js-content-viewer wafer-caas Fw(b) Fz(18px) Lh(23px) LineClamp(2,46px) Fz(17px)--sm1024 Lh(19px)--sm1024 LineClamp(2,38px)--sm1024 mega-item-header-link Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024 not-isInStreamVideoEnabled" data-uuid="0d27340a-369a-3291-8723-1065ec6b6e31" data-wf-caas-prefetch="1" data-wf-caas-uuid="0d27340a-369a-3291-8723-1065ec6b6e31" href="/news/investors-met-slowing-returns-capital-150602547.html"><u class="StretchedBox"></u>Investors Met With Slowing Returns on Capital At Open Text (NASDAQ:OTEX)</a>, <a class="js-content-viewer wafer-caas Fw(b) Fz(18px) Lh(23px) LineClamp(2,46px) Fz(17px)--sm1024 Lh(19px)--sm1024 LineClamp(2,38px)--sm1024 mega-item-header-link Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024 not-isInStreamVideoEnabled" data-uuid="02679cb3-9088-380a-9677-a43f677592e4" data-wf-caas-prefetch="1" data-wf-caas-uuid="02679cb3-9088-380a-9677-a43f677592e4" href="/news/2-tech-stocks-could-set-1
# ...

# %%
text = []
value=[]
for row in (table_rows):
    text.append(row.text)
    value.append(row['href'])

# %%
text
# Out:
# ['Investors Met With Slowing Returns on Capital At Open Text (NASDAQ:OTEX)',
#  '2 Tech Stocks That Could Set You up for Life',
#  'OpenText World EMEA gets underway, unveiling the newest Cloud Editions Innovations and reimagining the Future of Information Management']

# %%
#for i in range(len(value)):
    #value[i] = "www.finance.yahoo.com" + value[i]
#value
for i in range(len(value)):
    text[i] = tuple((text[i],value[i]))
text
# Out:
# [('Investors Met With Slowing Returns on Capital At Open Text (NASDAQ:OTEX)',
#   'www.finance.yahoo.com/news/investors-met-slowing-returns-capital-150602547.html'),
#  ('2 Tech Stocks That Could Set You up for Life',
#   'www.finance.yahoo.com/news/2-tech-stocks-could-set-160000147.html'),
#  ('OpenText World EMEA gets underway, unveiling the newest Cloud Editions Innovations and reimagining the Future of Information Management',
#   'www.finance.yahoo.com/news/opentext-world-emea-gets-underway-110000493.html')]
